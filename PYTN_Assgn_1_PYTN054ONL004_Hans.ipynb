# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hans8626\london_crime_by_lsoa.csv")

# %%
df1 = df.set_index('year',inplace=False)

# %%
df1.head()
# Out:
#       lsoa_code     borough               major_category  \
# year
# 2016  E01001116     Croydon                     Burglary
# 2016  E01001646   Greenwich  Violence Against the Person
# 2015  E01000677     Bromley  Violence Against the Person
# 2016  E01003774   Redbridge                     Burglary
# 2008  E01004563  Wandsworth                      Robbery
#
#                    minor_category  value  month
# year
# 2016  Burglary in Other Buildings      0     11
# 2016               Other violence      0     11
# 2015               Other violence      0      5
# 2016  Burglary in Other Buildings      0      3
# 2008            Personal Property      0      6

# %%
df.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
df2 = df.set_index('borough',inplace=False)

# %%
df2.head()
# Out:
#             lsoa_code               major_category  \
# borough
# Croydon     E01001116                     Burglary
# Greenwich   E01001646  Violence Against the Person
# Bromley     E01000677  Violence Against the Person
# Redbridge   E01003774                     Burglary
# Wandsworth  E01004563                      Robbery
#
#                          minor_category  value  year  month
# borough
# Croydon     Burglary in Other Buildings      0  2016     11
# Greenwich                Other violence      0  2016     11
# Bromley                  Other violence      0  2015      5
# Redbridge   Burglary in Other Buildings      0  2016      3
# Wandsworth            Personal Property      0  2008      6

# %%
len(df)
# Out:
# 13490604

# %%
df.shape
# Out:
# (13490604, 7)

# %%
df.tail()
# Out:
#           lsoa_code     borough               major_category  \
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
df.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %%
df['borough'].value_counts()
# Out:
# Croydon                   602100
# Barnet                    572832
# Ealing                    549396
# Bromley                   523908
# Lambeth                   519048
# Enfield                   511164
# Wandsworth                498636
# Brent                     490644
# Lewisham                  485136
# Southwark                 483300
# Newham                    471420
# Redbridge                 445716
# Hillingdon                442584
# Greenwich                 421200
# Hackney                   417744
# Haringey                  413856
# Tower Hamlets             412128
# Waltham Forest            406296
# Havering                  399600
# Hounslow                  395928
# Bexley                    385668
# Camden                    378432
# Westminster               366660
# Harrow                    365688
# Islington                 359208
# Merton                    339876
# Hammersmith and Fulham    328752
# Sutton                    322488
# ...

# %%
df.loc[df['major_category'] == 'Robbery','minor_category'].value_counts()
# Out:
# Personal Property    520668
# Business Property    418716
# Name: minor_category, dtype: int64

# %%
df.loc[df['major_category'] == 'Robbery','value'].max()
# Out:
# 53

# %%
df.loc[df['major_category'] == 'Criminal Damage','value'].max()
# Out:
# 49

# %%
df.loc[df['major_category'] == 'Robbery','major_category'].value_counts()
# Out:
# Robbery    939384
# Name: major_category, dtype: int64

# %%
df.loc[df['borough'] == 'Croydon','major_category'].value_counts()
# Out:
# Theft and Handling             176256
# Violence Against the Person    143424
# Criminal Damage                 94176
# Drugs                           51948
# Burglary                        47520
# Robbery                         43740
# Other Notifiable Offences       30564
# Fraud or Forgery                 9396
# Sexual Offences                  5076
# Name: major_category, dtype: int64

# %%
df.isnull().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# dtype: int64

# %%
df.columns.values
# Out:
# array(['lsoa_code', 'borough', 'major_category', 'minor_category',
#        'value', 'year', 'month'], dtype=object)

# %%
df.index.values
# Out:
# array([       0,        1,        2, ..., 13490601, 13490602, 13490603],
#       dtype=int64)

# %%
df.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
df1 = df

# %%
df1
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
df1.set_index('year',inplace=True)
df1
# Out:
#       lsoa_code     borough               major_category  \
# year
# 2016  E01001116     Croydon                     Burglary
# 2016  E01001646   Greenwich  Violence Against the Person
# 2015  E01000677     Bromley  Violence Against the Person
# 2016  E01003774   Redbridge                     Burglary
# 2008  E01004563  Wandsworth                      Robbery
# ...         ...         ...                          ...
# 2015  E01000504       Brent              Criminal Damage
# 2015  E01002504  Hillingdon                      Robbery
# 2011  E01004165      Sutton                     Burglary
# 2011  E01001134     Croydon                      Robbery
# 2015  E01003413      Merton  Violence Against the Person
#
#                    minor_category  value  month
# year
# 2016  Burglary in Other Buildings      0     11
# 2016               Other violence      0     11
# 2015               Other violence      0      5
# 2016  Burglary in Other Buildings      0      3
# ...

# %%
import matplotlib.pyplot as plt

# %%
df1.column name
# Out:
#   File "<ipython-input-86-a879bfbabed2>", line 1
#     df1.column name
#                ^
# SyntaxError: invalid syntax

# %%
df1.borough
# Out:
# year
# 2016       Croydon
# 2016     Greenwich
# 2015       Bromley
# 2016     Redbridge
# 2008    Wandsworth
#            ...
# 2015         Brent
# 2015    Hillingdon
# 2011        Sutton
# 2011       Croydon
# 2015        Merton
# Name: borough, Length: 13490604, dtype: object

# %%
print(df1.loc[2016])
# Out:
#       lsoa_code                 borough               major_category  \
# year
# 2016  E01001116                 Croydon                     Burglary
# 2016  E01001646               Greenwich  Violence Against the Person
# 2016  E01003774               Redbridge                     Burglary
# 2016  E01004177                  Sutton           Theft and Handling
# 2016  E01002398              Hillingdon           Theft and Handling
# ...         ...                     ...                          ...
# 2016  E01003920               Southwark  Violence Against the Person
# 2016  E01004742             Westminster           Theft and Handling
# 2016  E01002823  Kensington and Chelsea           Theft and Handling
# 2016  E01004100                  Sutton                        Drugs
# 2016  E01000193                  Barnet              Criminal Damage
#
#                               minor_category  value  month
# year
# 2016             Burglary in Other Buildings      0     11
# ...

# %%
df1
# Out:
#       lsoa_code     borough               major_category  \
# year
# 2016  E01001116     Croydon                     Burglary
# 2016  E01001646   Greenwich  Violence Against the Person
# 2015  E01000677     Bromley  Violence Against the Person
# 2016  E01003774   Redbridge                     Burglary
# 2008  E01004563  Wandsworth                      Robbery
# ...         ...         ...                          ...
# 2015  E01000504       Brent              Criminal Damage
# 2015  E01002504  Hillingdon                      Robbery
# 2011  E01004165      Sutton                     Burglary
# 2011  E01001134     Croydon                      Robbery
# 2015  E01003413      Merton  Violence Against the Person
#
#                    minor_category  value  month
# year
# 2016  Burglary in Other Buildings      0     11
# 2016               Other violence      0     11
# 2015               Other violence      0      5
# 2016  Burglary in Other Buildings      0      3
# ...

# %%
df2
# Out:
#             lsoa_code               major_category  \
# borough
# Croydon     E01001116                     Burglary
# Greenwich   E01001646  Violence Against the Person
# Bromley     E01000677  Violence Against the Person
# Redbridge   E01003774                     Burglary
# Wandsworth  E01004563                      Robbery
# ...               ...                          ...
# Brent       E01000504              Criminal Damage
# Hillingdon  E01002504                      Robbery
# Sutton      E01004165                     Burglary
# Croydon     E01001134                      Robbery
# Merton      E01003413  Violence Against the Person
#
#                          minor_category  value  year  month
# borough
# Croydon     Burglary in Other Buildings      0  2016     11
# Greenwich                Other violence      0  2016     11
# Bromley                  Other violence      0  2015      5
# Redbridge   Burglary in Other Buildings      0  2016      3
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13490604 entries, Croydon to Merton
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   major_category  object
#  2   minor_category  object
#  3   value           int64
#  4   year            int64
#  5   month           int64
# dtypes: int64(3), object(3)
# memory usage: 720.5+ MB

# %%
df3 = df2.groupby('borough',sort=False)['value'].sum()
df3
# Out:
# borough
# Croydon                   260294
# Greenwich                 181568
# Bromley                   184349
# Redbridge                 183562
# Wandsworth                204741
# Ealing                    251562
# Hounslow                  186772
# Newham                    262024
# Sutton                    100987
# Haringey                  213272
# Lambeth                   292178
# Richmond upon Thames       96771
# Hillingdon                209680
# Havering                  138947
# Barking and Dagenham      149447
# Kingston upon Thames       89306
# Westminster               455028
# Hackney                   217119
# Enfield                   193880
# Harrow                    116848
# Lewisham                  215137
# Brent                     227551
# Southwark                 278809
# Barnet                    212191
# Waltham Forest            203879
# Camden                    275147
# Bexley                    114136
# Kensington and Chelsea    171981
# ...

# %%
df4 = df.DataFrame('borough',columns=['major_category','minor_category','year','value'])
df4
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-31dd4c75c4a2> in <module>
# ----> 1 df4 = df.DataFrame('borough',columns=['major_category','minor_category','year','value'])
#       2 df4
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
# %matplotlib inline

# %%
df2[df2['major_category'] == 'Burglary'].groupby('year')['value'].sum().plot()

# %%
df2.groupby('year')['value'].sum().plot(kind='line',figsize=(20,5))

# %%
df2['major_category'].value_counts().head(20).plot(kind='bar')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
Croydon = df2.loc['Croydon', 'major_category'].value_counts()
Croydon.tail()
# Out:
# Burglary                     47520
# Robbery                      43740
# Other Notifiable Offences    30564
# Fraud or Forgery              9396
# Sexual Offences               5076
# Name: major_category, dtype: int64

# %%
Croydon.plot(kind = 'line', figsize = (20,5))

# %%
Croydon.plot(kind = 'bar', figsize = (20,5))

# %%
df4 = df2.groupby('major_category',sort=False)['value'].sum()

# %%
df4 = df2.groupby('borough',sort=False)['major_category','value'].sum()
df4
# Out:
# <ipython-input-17-a71988b052f7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df4 = df2.groupby('borough',sort=False)['major_category','value'].sum()
#                          value
# borough
# Croydon                 260294
# Greenwich               181568
# Bromley                 184349
# Redbridge               183562
# Wandsworth              204741
# Ealing                  251562
# Hounslow                186772
# Newham                  262024
# Sutton                  100987
# Haringey                213272
# Lambeth                 292178
# Richmond upon Thames     96771
# Hillingdon              209680
# Havering                138947
# Barking and Dagenham    149447
# Kingston upon Thames     89306
# Westminster             455028
# Hackney                 217119
# Enfield                 193880
# Harrow                  116848
# Lewisham                215137
# ...

# %%
df4 = df2.groupby(['borough','major_category'],sort=False)['value'].sum()
df4
# Out:
# borough         major_category
# Croydon         Burglary                       33376
# Greenwich       Violence Against the Person    52897
# Bromley         Violence Against the Person    46759
# Redbridge       Burglary                       26735
# Wandsworth      Robbery                         8398
#                                                ...
# Hackney         Sexual Offences                   46
# City of London  Theft and Handling               561
# Waltham Forest  Sexual Offences                   34
# Sutton          Sexual Offences                   20
# City of London  Criminal Damage                   16
# Name: value, Length: 295, dtype: int64

# %%
df2.groupby('year')['value'].sum().plot(kind='line',figsize=(20,5))

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
df_major = df2.groupby(['year','major_category'],sort=True)['value'].sum()

# %%
df_major
# Out:
# year  major_category
# 2008  Burglary                        88092
#       Criminal Damage                 91872
#       Drugs                           68804
#       Fraud or Forgery                 5325
#       Other Notifiable Offences       10112
#                                       ...
# 2016  Other Notifiable Offences       15809
#       Robbery                         22528
#       Sexual Offences                     0
#       Theft and Handling             294133
#       Violence Against the Person    232381
# Name: value, Length: 81, dtype: int64

# %%
df_major[2016].groupby('major_category').sum().plot(kind='pie',figsize=(20,20))
plt.xlabel('Number of Crimes')
plt.ylabel('Major Category of Crime',)
plt.title('Crimes Happen during year of 2016')
plt.show()

# %%
df_minor = df2.groupby(['year','minor_category'],sort=True)['value'].sum()

# %%
df_minor[2010].plot(kind='barh',figsize =(10,20))

# %%
df1.index
# Out:
# Int64Index([2016, 2016, 2015, 2016, 2008, 2012, 2010, 2013, 2013, 2016,
#             ...
#             2008, 2012, 2010, 2014, 2012, 2015, 2015, 2011, 2011, 2015],
#            dtype='int64', name='year', length=13490604)

# %%
df2.index
# Out:
# Index(['Croydon', 'Greenwich', 'Bromley', 'Redbridge', 'Wandsworth', 'Ealing',
#        'Ealing', 'Hounslow', 'Newham', 'Sutton',
#        ...
#        'Greenwich', 'Croydon', 'Bromley', 'Brent', 'Hillingdon', 'Brent',
#        'Hillingdon', 'Sutton', 'Croydon', 'Merton'],
#       dtype='object', name='borough', length=13490604)

# %%
df_values = df1.sort_values(by='year',ascending=True)
df_values
# Out:
#       lsoa_code                 borough               major_category  \
# year
# 2008  E01001255                  Ealing  Violence Against the Person
# 2008  E01002790               Islington  Violence Against the Person
# 2008  E01003634                  Newham                     Burglary
# 2008  E01033698                 Hackney           Theft and Handling
# 2008  E01004565              Wandsworth                        Drugs
# ...         ...                     ...                          ...
# 2016  E01001309                  Ealing           Theft and Handling
# 2016  E01001534                 Enfield              Criminal Damage
# 2016  E01004357          Waltham Forest  Violence Against the Person
# 2016  E01001954  Hammersmith and Fulham                        Drugs
# 2016  E01001116                 Croydon                     Burglary
#
#                               minor_category  value  month
# year
# 2008                     Assault with Injury      0      6
# ...

# %%
df1.tail()
# Out:
#       lsoa_code     borough               major_category  \
# year
# 2015  E01000504       Brent              Criminal Damage
# 2015  E01002504  Hillingdon                      Robbery
# 2011  E01004165      Sutton                     Burglary
# 2011  E01001134     Croydon                      Robbery
# 2015  E01003413      Merton  Violence Against the Person
#
#                    minor_category  value  month
# year
# 2015  Criminal Damage To Dwelling      0      2
# 2015            Personal Property      1      6
# 2011       Burglary in a Dwelling      0      2
# 2011            Business Property      0      5
# 2015                 Wounding/GBH      0      6

# %%
df_Croydon = df1.loc['Croydon', axis=0]
# Out:
#   File "<ipython-input-35-835e0fcb3cbf>", line 1
#     df_Croydon = df1.loc['Croydon', axis=0]
#                                         ^
# SyntaxError: invalid syntax

# %%
df1.head()
# Out:
#       lsoa_code     borough               major_category  \
# year
# 2016  E01001116     Croydon                     Burglary
# 2016  E01001646   Greenwich  Violence Against the Person
# 2015  E01000677     Bromley  Violence Against the Person
# 2016  E01003774   Redbridge                     Burglary
# 2008  E01004563  Wandsworth                      Robbery
#
#                    minor_category  value  month
# year
# 2016  Burglary in Other Buildings      0     11
# 2016               Other violence      0     11
# 2015               Other violence      0      5
# 2016  Burglary in Other Buildings      0      3
# 2008            Personal Property      0      6

# %%
df1
# Out:
#       lsoa_code     borough               major_category  \
# year
# 2016  E01001116     Croydon                     Burglary
# 2016  E01001646   Greenwich  Violence Against the Person
# 2015  E01000677     Bromley  Violence Against the Person
# 2016  E01003774   Redbridge                     Burglary
# 2008  E01004563  Wandsworth                      Robbery
# ...         ...         ...                          ...
# 2015  E01000504       Brent              Criminal Damage
# 2015  E01002504  Hillingdon                      Robbery
# 2011  E01004165      Sutton                     Burglary
# 2011  E01001134     Croydon                      Robbery
# 2015  E01003413      Merton  Violence Against the Person
#
#                    minor_category  value  month
# year
# 2016  Burglary in Other Buildings      0     11
# 2016               Other violence      0     11
# 2015               Other violence      0      5
# 2016  Burglary in Other Buildings      0      3
# ...

# %%
df3=df1.droplevel('year',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-5f6c34426b34> in <module>
# ----> 1 df3=df1.droplevel('year',axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in droplevel(self, level, axis)
#     743         """
#     744         labels = self._get_axis(axis)
# --> 745         new_labels = labels.droplevel(level)
#     746         result = self.set_axis(new_labels, axis=axis, inplace=False)
#     747         return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in droplevel(self, level)
#    1504             level = [level]
#    1505
# -> 1506         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1507
#    1508         if len(level) == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in <genexpr>(.0)
#    1504             level = [level]
#    1505
# ...

# %%
df.head()
# Out:
#    lsoa_code     borough               major_category  \
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
# 5  E01001320      Ealing           Theft and Handling
# 6  E01001342      Ealing  Violence Against the Person
# 7  E01002633    Hounslow                      Robbery
#
#                 minor_category  value  year  month
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6
# 5                  Other Theft      0  2012      5
# 6             Offensive Weapon      0  2010      7
# 7            Personal Property      0  2013      4

# %%
Croydon_Greenwich = df.loc[['borough'] == 'Croydon','year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-96cb46ef8f2e> in <module>
# ----> 1 Croydon_Greenwich = df.loc[['borough'] == 'Croydon','year']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13490601 entries, 3 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 1.4+ GB

# %%
df.sort_values('borough')
# Out:
#           lsoa_code               borough               major_category  \
# 396337    E01000086  Barking and Dagenham           Theft and Handling
# 2791705   E01000102  Barking and Dagenham  Violence Against the Person
# 6957955   E01000067  Barking and Dagenham           Theft and Handling
# 6957953   E01000088  Barking and Dagenham                        Drugs
# 6957944   E01000012  Barking and Dagenham                      Robbery
# ...             ...                   ...                          ...
# 8178873   E01033595           Westminster           Theft and Handling
# 10103431  E01004724           Westminster  Violence Against the Person
# 2607963   E01033607           Westminster              Criminal Damage
# 2608077   E01004762           Westminster           Theft and Handling
# 4770282   E01004686           Westminster  Violence Against the Person
#
#                          minor_category  value  year  month
# ...

# %%
df.filter(like=['Croydon','Greenwich'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-50cf6ad412bf> in <module>
# ----> 1 df.filter(like=['Croydon','Greenwich'],axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4703                 return like in ensure_str(x)
#    4704
# -> 4705             values = labels.map(f)
#    4706             return self.loc(axis=axis)[values]
#    4707         elif regex:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in map(self, mapper, na_action)
#    4563         from pandas.core.indexes.multi import MultiIndex
#    4564
# -> 4565         new_values = super()._map_values(mapper, na_action=na_action)
#    4566
#    4567         attributes = self._get_attributes_dict()
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1143
# ...

# %%
df['borough'].str.contains('Croydon')
# Out:
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
#             ...
# 13490599    False
# 13490600    False
# 13490601    False
# 13490602     True
# 13490603    False
# Name: borough, Length: 13490601, dtype: bool

# %%
df3 = df2.loc[['Croydon','Greenwich']]

# %%
df4 = df3.set_index('major_category',inplace=False)
df4.loc['Theft and Handling']
df5 = df4.set_index('year',inplace=False)
df5.loc[2016]
# Out:
#       lsoa_code                          minor_category  value  month
# year
# 2016  E01001116             Burglary in Other Buildings      0     11
# 2016  E01001162                       Personal Property      0      1
# 2016  E01001139  Motor Vehicle Interference & Tampering      0      3
# 2016  E01001100                            Wounding/GBH      0      6
# 2016  E01001040                      Other Theft Person      0      2
# ...         ...                                     ...    ...    ...
# 2016  E01001694                            Wounding/GBH      0      4
# 2016  E01001672                          Other violence      1     10
# 2016  E01033746                Theft From Motor Vehicle      0     10
# 2016  E01001661                     Assault with Injury      2      1
# 2016  E01033744                             Other Drugs      0      9
#
# [113700 rows x 4 columns]

# %%
df4 = df2[df2['Croydon','Greenwich']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Croydon', 'Greenwich')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-70f59bdccf50> in <module>
# ...

# %%
df_transposed = df_values.T

# %%
df_transposed.head()
# Out:
# year                                   2008                         2008  \
# lsoa_code                         E01001255                    E01002790
# borough                              Ealing                    Islington
# major_category  Violence Against the Person  Violence Against the Person
# minor_category          Assault with Injury                   Harassment
# value                                     0                            0
#
# year                                   2008  \
# lsoa_code                         E01003634
# borough                              Newham
# major_category                     Burglary
# minor_category  Burglary in Other Buildings
# value                                     0
#
# year                                              2008                 2008  \
# lsoa_code                                    E01033698            E01004565
# borough                                        Hackney           Wandsworth
# ...

# %%
df_transposed = df5

# %%
df5.items()
# Out:
# <generator object DataFrame.items at 0x000001AA0E8D4CF0>
